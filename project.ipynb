# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile

# %%
sr, data = wavfile.read("capped.wav")

# %%
duration = len(data) / sr 
time_array = np.linspace(0, duration, len(data))

# %%
time_array
# Out:
# array([0.00000000e+00, 2.26757445e-05, 4.53514890e-05, ...,
#        6.82782313e+01, 6.82782540e+01, 6.82782766e+01], shape=(3011072,))

# %%
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

# %%
    # Plot waveform
plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of closed resonator")
plt.show()

    # Plot frequency spectrum
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(40, 1100)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("Frequency Spectrum of closed resonator")
plt.show()

# %%
plt.specgram(data)
plt.figure(figsize=(10, 4,))

# %%
plt.figure(figsize=(10, 4,))
plt.specgram(data)

plt.xlim(0, 1e6)  # Set x-axis limits
plt.ylim(0, 0.2) # Set y-axis limits
# Out:
# (0.0, 0.2)

# %%
sr2, data2 = wavfile.read("uncapped.wav")

# %%
duration2 = len(data2) / sr2
time_array2 = np.linspace(0, duration2, len(data2)) 
if data2.ndim > 1:
        data2 = data2[:, 0]

 # Perform FFT
fft_result2 = np.fft.fft(data2)

    # Calculate frequencies corresponding to the FFT result
frequencies2 = np.fft.fftfreq(len(data2), d=1/sr2)

    
positive_frequencies2 = frequencies2[:len(data2)//2]
magnitude_spectrum2 = np.abs(fft_result2[:len(data2)//2])

# %%
plt.figure(figsize=(10, 4))
plt.plot(time_array2, data2)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of resonator with one end open")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies2, magnitude_spectrum2)
plt.xlim(40, 1100)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("Frequency Spectrum of resonator with one end open")
plt.show()

# %%
plt.specgram(data2)
plt.figure(figsize=(10, 4,))

# %%
plt.figure(figsize=(10, 4,))
plt.specgram(data2)

plt.xlim(0, 1e6)  
plt.ylim(0, 0.2)
# Out:
# (0.0, 0.2)

# %%
plt.plot(time_array2,frequencies2)
plt.xlim(0,50)
plt.ylim(0,1e5)
# Out:
# (0.0, 100000.0)
