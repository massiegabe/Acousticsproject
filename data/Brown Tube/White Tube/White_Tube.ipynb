# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile

# %%
l = 21.25/39.37
v = 343 #m/s
n=np.array([1,3,5,7]) # harmonics
freq = (n*v)/(4*l)
lam = (4*l)/n
freq
# Out:
# array([ 158.86952941,  476.60858824,  794.34764706, 1112.08670588])

# %%
sr, data = wavfile.read("100hz_1khz_background.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of 100hz-1khz background")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 1000)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("100hz-1khz background")
plt.show()

# %%
sr, data = wavfile.read("100hz-1khz open.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of 100hz-1khz with one open end")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 1000)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("100hz-1khz with one open end")
plt.show()

# %%
sr, data = wavfile.read("100hz-1khz open.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of 100hz-1khz with one open end")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 1000)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("100hz-1khz with one open end")
plt.show()

# %%
sr, data = wavfile.read("450-480hz background.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of 450hz-480hz background")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(450, 480)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("450hz-480hz background")
plt.show()

# %%
sr, data = wavfile.read("450-480hz open.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of 450hz-480hz with one open end")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(450, 480)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("450hz-480hz with one open end")
plt.show()

# %%
sr, data = wavfile.read("100-200 background.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of 100hz-200hz background")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 200)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("100hz-200hz background")
plt.show()

# %%
sr, data = wavfile.read("100-200hz Open.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of 100hz-200hz with one open end")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 200)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("100hz-200hz with one open end")
plt.show()

# %%
sr, data = wavfile.read("test.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of test")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 1000)  
plt.ylim(0,2e8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("test")
plt.show()

# %%
sr, data = wavfile.read("test background.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of background test")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 1000)  
plt.ylim(0,2e8)
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("test background")
plt.show()

# %%
sr, data = wavfile.read("small tube test background.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of small background test")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 1000)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("test background")
plt.show()

# %%
sr, data = wavfile.read("small tube test.wav")

duration = len(data) / sr
time_array = np.linspace(0, duration, len(data)) 
if data.ndim > 1:
        data = data[:, 0]

 # Perform FFT
fft_result = np.fft.fft(data)

    # Calculate frequencies corresponding to the FFT result
frequencies = np.fft.fftfreq(len(data), d=1/sr)

    
positive_frequencies = frequencies[:len(data)//2]
magnitude_spectrum = np.abs(fft_result[:len(data)//2])

plt.figure(figsize=(10, 4))
plt.plot(time_array, data)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Audio Waveform of small test")
plt.show()
plt.figure(figsize=(10, 4,))
plt.plot(positive_frequencies, magnitude_spectrum)
plt.xlim(100, 1000)  
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")
plt.title("test")
plt.show()
